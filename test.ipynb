# %%
import pandas as pd

# %%
df = pd.read_csv("data/agricultural.csv")
df.head()
# Out:
#        farm_id        region   state                agro_zone crop_type  \
# 0  FARM_000001    Southsouth  Rivers             Humid Forest    Pepper
# 1  FARM_000002     Northeast   Gombe            Sudan Savanna     Beans
# 2  FARM_000003     Northwest  Jigawa            Sudan Savanna   Sorghum
# 3  FARM_000004  Northcentral   Benue  Northern Guinea Savanna     Maize
# 4  FARM_000005     Southwest    Osun             Humid Forest       Yam
#
#     crop_variety  soil_type  farm_size_ha  soil_pH  soil_nitrogen  ...  \
# 0  Nsukka Yellow  Lateritic           0.9      6.5           17.5  ...
# 1     IT89KD-288      Sandy           2.2      7.3           21.8  ...
# 2    Local Kaura      Loamy           2.9      5.0           24.1  ...
# 3    Local White     Clayey           0.5      5.1           23.4  ...
# 4       D. alata      Loamy           4.6      6.7           18.4  ...
#
#    fertilizer_amount_kg_ha  irrigation_type    pest_type  pest_severity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   farm_id                  20000 non-null  object
#  1   region                   20000 non-null  object
#  2   state                    20000 non-null  object
#  3   agro_zone                20000 non-null  object
#  4   crop_type                20000 non-null  object
#  5   crop_variety             20000 non-null  object
#  6   soil_type                20000 non-null  object
#  7   farm_size_ha             19399 non-null  float64
#  8   soil_pH                  20000 non-null  float64
#  9   soil_nitrogen            19385 non-null  float64
#  10  soil_phosphorus          19433 non-null  float64
#  11  soil_potassium           19364 non-null  float64
#  12  rainfall_mm              20000 non-null  float64
#  13  temperature_C            20000 non-null  float64
# ...
